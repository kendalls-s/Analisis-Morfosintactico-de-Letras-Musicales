# %%
# =========================
# IMPORTAR LIBRERIAS
# =========================

import pandas as pd
import re
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Descargar diccionario VADER (solo primera vez)
nltk.download('vader_lexicon')


# =========================
# 1. CARGAR DATASET
# =========================

ruta_archivo = "C:\\Users\\Roberto\\Downloads\\test.csv\\test.csv"
df = pd.read_csv(ruta_archivo)



# =========================
# 3. ANALISIS DE EMOCIONES
# =========================

sia = SentimentIntensityAnalyzer()

def detectar_emocion(texto):

    scores = sia.polarity_scores(str(texto))

    compound = scores['compound']
    pos = scores['pos']
    neg = scores['neg']

    if compound >= 0.6:
        return "Happy"
    elif 0.3 <= compound < 0.6:
        return "Excited"
    elif compound <= -0.6:
        return "Angry"
    elif -0.6 < compound <= -0.3:
        return "Sad"
    else:
        return "Neutral"


# Crear columna Emotion usando texto limpio
df["Emotion"] = df["Clean_Lyrics"].apply(detectar_emocion)


# =========================
# 4. GUARDAR DATASET FINAL
# =========================


df.to_csv("songs_with_emotions.csv", index=False)


# =========================
# 5. MOSTRAR RESULTADOS
# =========================

print(df.head())
print("\nCantidad de canciones por emoción:")
print(df["Emotion"].value_counts())
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                    Song  Song year                   Artist    Genre  \
# 0         craftsmanship       2005                  buck-65  Hip-Hop
# 1           come-on-out       2012               the-elwins    Indie
# 2                  riot       2013  bullet-for-my-valentine    Metal
# 3  that-s-what-girls-do       2007             dream-street      Pop
# 4   believe-in-a-dollar       2012                  cassidy  Hip-Hop
#
#                                               Lyrics  \
# 0  Most folks spend their days daydreaming of fin...
# 1  Take your cold hands and put them on my face\n...
# 2  Are you ready it's time for war\nWe'll break d...
# 3  You ask me why I change the color of my hair\n...
# 4  Do you believe in magic in a young girl's hear...
#
#                                         Clean_Lyrics Emotion
# 0  most folks spend their days daydreaming of fin...   Happy
# 1  take your cold hands and put them on my face s...   Happy
# 2  are you ready its time for war well break down...   Angry
# 3  you ask me why i change the color of my hair y...   Happy
# 4  do you believe in magic in a young girls heart...   Happy
#
# Cantidad de canciones por emoción:
# Emotion
# Happy      4142
# Angry      2615
# Neutral     540
# Excited     338
# Sad         300
# Name: count, dtype: int64
