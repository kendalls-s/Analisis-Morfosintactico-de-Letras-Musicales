# %% [markdown]
# # Importacion de librerias para NLTK

# %% [markdown]
# ## Configurar SSL

# %%
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

print("✓ Configuración SSL aplicada")
# Out:
# ✓ Configuración SSL aplicada

# %% [markdown]
# ## Importaciones

# %%
import sys
import os
import warnings
import nltk
from pathlib import Path
warnings.filterwarnings('ignore')
sys.path.append(os.path.abspath(".."))
from src.data import carga_limpios
from src.data import token_nltk
from src.pos_tagging import apply_pos_tagging

print("✓ Librerías importadas correctamente")

# Intentar descargar recursos de NLTK de forma silenciosa
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt', quiet=True)

try:
    nltk.data.find('taggers/averaged_perceptron_tagger')
except LookupError:
    nltk.download('averaged_perceptron_tagger', quiet=True)

print("✓ Recursos de NLTK listos")
# Out:
# ✓ Librerías importadas correctamente
# ✓ Recursos de NLTK listos

# %%
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
#Si no sirve ejecutar estos comandos
#SOLO PARA VERSION PYTHON 3.13
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Roberto\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %% [markdown]
# ## Carga de datos

# %%
df= carga_limpios()
df.head()
# Out:
#                    Song  Song year                   Artist    Genre  \
# 0         craftsmanship       2005                  buck-65  Hip-Hop
# 1           come-on-out       2012               the-elwins    Indie
# 2                  riot       2013  bullet-for-my-valentine    Metal
# 3  that-s-what-girls-do       2007             dream-street      Pop
# 4   believe-in-a-dollar       2012                  cassidy  Hip-Hop
#
#                                               Lyrics
# 0  Most folks spend their days daydreaming of fin...
# 1  Take your cold hands and put them on my face S...
# 2  Are you ready its time for war Well break down...
# 3  You ask me why I change the color of my hair Y...
# 4  Do you believe in magic in a young girls heart...

# %% [markdown]
# ## Letras tokenizadas

# %%
df= token_nltk(df)
print("Archivo generado correctamente")
df.head()
# Out:
# Archivo generado correctamente
#                    Song  Song year                   Artist    Genre  \
# 0         craftsmanship       2005                  buck-65  Hip-Hop
# 1           come-on-out       2012               the-elwins    Indie
# 2                  riot       2013  bullet-for-my-valentine    Metal
# 3  that-s-what-girls-do       2007             dream-street      Pop
# 4   believe-in-a-dollar       2012                  cassidy  Hip-Hop
#
#                                               Lyrics  \
# 0  Most folks spend their days daydreaming of fin...
# 1  Take your cold hands and put them on my face S...
# 2  Are you ready its time for war Well break down...
# 3  You ask me why I change the color of my hair Y...
# 4  Do you believe in magic in a young girls heart...
#
#                                               tokens
# 0  [Most, folks, spend, their, days, daydreaming,...
# 1  [Take, your, cold, hands, and, put, them, on, ...
# 2  [Are, you, ready, its, time, for, war, Well, b...
# 3  [You, ask, me, why, I, change, the, color, of,...
# 4  [Do, you, believe, in, magic, in, a, young, gi...

# %% [markdown]
# ## Pos tagger

# %%
df = apply_pos_tagging(df)
print("Archivo generado correctamente")
df.head()
# Out:
# Archivo generado correctamente
#                    Song  Song year                   Artist    Genre  \
# 0         craftsmanship       2005                  buck-65  Hip-Hop
# 1           come-on-out       2012               the-elwins    Indie
# 2                  riot       2013  bullet-for-my-valentine    Metal
# 3  that-s-what-girls-do       2007             dream-street      Pop
# 4   believe-in-a-dollar       2012                  cassidy  Hip-Hop
#
#                                               Lyrics  \
# 0  Most folks spend their days daydreaming of fin...
# 1  Take your cold hands and put them on my face S...
# 2  Are you ready its time for war Well break down...
# 3  You ask me why I change the color of my hair Y...
# 4  Do you believe in magic in a young girls heart...
#
#                                               tokens  \
# 0  [Most, folks, spend, their, days, daydreaming,...
# 1  [Take, your, cold, hands, and, put, them, on, ...
# 2  [Are, you, ready, its, time, for, war, Well, b...
# 3  [You, ask, me, why, I, change, the, color, of,...
# 4  [Do, you, believe, in, magic, in, a, young, gi...
#
#                                             pos_tags
# 0  [(Most, JJS), (folks, NNS), (spend, VBP), (the...
# 1  [(Take, VB), (your, PRP$), (cold, JJ), (hands,...
# 2  [(Are, NNP), (you, PRP), (ready, JJ), (its, PR...
# 3  [(You, PRP), (ask, VBP), (me, PRP), (why, WRB)...
# 4  [(Do, VBP), (you, PRP), (believe, VB), (in, IN...
