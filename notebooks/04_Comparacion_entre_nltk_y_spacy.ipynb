# %% [markdown]
# # Comparacion entre nltk y spacy

# %% [markdown]
# ### Importaciones

# %%
import ast
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.data import carga_pos_nltk,carga_pos_spacy
from src.pos_tagging import comparar_nltk_spacy_csv

# %% [markdown]
# ### Carga de datos

# %%
# Cargar los dos CSV
df_nltk  = carga_pos_nltk()
df_spacy = carga_pos_spacy()

#Leer como lista no como str
df_nltk['pos_tags']       = df_nltk['pos_tags'].apply(ast.literal_eval)
df_spacy['pos_tags_spacy'] = df_spacy['pos_tags_spacy'].apply(ast.literal_eval)

# %% [markdown]
# ### Comparacion

# %%
 comparar_nltk_spacy_csv(df_nltk, df_spacy, indice=0)
# Out:
# =====================================================================================
# COMPARACIÓN: NLTK vs spaCy
# =====================================================================================
# Canción : craftsmanship
# Artista : buck-65
# Género  : Hip-Hop
#
# Token                NLTK (Penn)     spaCy Universal    spaCy Fine      Lemma
# -------------------------------------------------------------------------------------
# Most                 JJS             ADJ                JJS             Most
# folks                NNS             NOUN               NNS             folk
# spend                VBP             VERB               VBP             spend
# their                PRP$            PRON               PRP$            their
# days                 NNS             NOUN               NNS             day
# daydreaming          VBG             VERB               VBG             daydream
# of                   IN              ADP                IN              of
# finding              VBG             NOUN               NN              finding *
# clues                NNS             VERB               VBZ             clue *
# My                   NNP             PRON               PRP$            my *
# whole                JJ              ADJ                JJ              whole
# life                 NN              NOUN               NN              life
# been                 VBN             AUX                VBN             be
# here                 RB              ADV                RB              here
# at                   IN              ADP                IN              at
# the                  DT              DET                DT              the
# train                NN              NOUN               NN              train
# station              NN              NOUN               NN              station
# shining              VBG             VERB               VBG             shin
# shoes                NNS             NOUN               NNS             shoe
# I                    PRP             PRON               PRP             I
# started              VBD             VERB               VBD             start
# when                 WRB             SCONJ              WRB             when
# was                  VBD             AUX                VBD             be
# nine                 CD              NUM                CD              nine
# on                   IN              ADP                IN              on
# my                   PRP$            PRON               PRP$            my
# own                  JJ              ADJ                JJ              own
# and                  CC              CCONJ              CC              and
# taught               VBD             VERB               VBD             teach
# myself               PRP             PRON               PRP             myself
# No                   NNP             DET                DT              no *
# complaints           NNS             NOUN               NNS             complaint
# doing                VBG             VERB               VBG             do
# pretty               RB              ADV                RB              pretty
# good                 JJ              ADJ                JJ              good
# got                  VBD             VERB               VBP             got *
# health               NN              NOUN               NN              health
# Memories             NNPS            PROPN              NNP             Memories *
# callouses            NNS             VERB               VBZ             callous *
# hearings             NNS             NOUN               NNS             hearing
# probably             RB              ADV                RB              probably
# next                 JJ              ADJ                JJ              next
# to                   TO              ADP                IN              to *
# go                   VB              VERB               VB              go
# Sometimes            RB              ADV                RB              sometimes
# do                   VBP             AUX                VBP             do
# a                    DT              DET                DT              a
# little               RB              ADJ                JJ              little *
# handywork            NN              NOUN               NN              handywork
# for                  IN              SCONJ              IN              for
# extra                JJ              ADJ                JJ              extra
# dough                NN              NOUN               NN              dough
# But                  CC              CCONJ              CC              but
# mostly               RB              ADV                RB              mostly
# this                 DT              PRON               DT              this
# is                   VBZ             AUX                VBZ             be
# how                  WRB             SCONJ              WRB             how
# time                 NN              NOUN               NN              time
# And                  CC              CCONJ              CC              and
# perfected            VBD             VERB               VBN             perfect *
# technique            NN              NOUN               NN              technique
# call                 VBP             VERB               VBP             call
# dry                  JJ              ADJ                JJ              dry
# shine                NN              VERB               VB              shine *
# Some                 DT              DET                DT              some
# guys                 NNS             NOUN               NNS             guy
# use                  VB              VERB               VB              use
# lots                 NNS             NOUN               NNS             lot
# water                NN              NOUN               NN              water
# shoe                 NN              NOUN               NN              shoe
# but                  CC              CCONJ              CC              but
# then                 RB              ADV                RB              then
# its                  PRP$            PRON               PRP$            its
# out                  RP              NOUN               NN              out *
# in                   IN              ADP                IN              in
# open                 JJ              ADJ                JJ              open
# air                  NN              NOUN               NN              air
# The                  DT              DET                DT              the
# gone                 VBN             VERB               VBN             go
# minutes              NNS             NOUN               NNS             minute
# That                 IN              PRON               DT              that *
# approach             NN              NOUN               NN              approach
# job                  NN              NOUN               NN              job
# dumb                 JJ              ADJ                JJ              dumb
# fact                 NN              NOUN               NN              fact
# Dollars              NNP             NOUN               NNS             dollar *
# donuts               VB              NOUN               NNS             donut *
# that                 IN              PRON               WDT             that *
# customer             NN              NOUN               NN              customer
# be                   VB              AUX                VB              be
# coming               VBG             VERB               VBG             come
# back                 RB              ADV                RB              back
# This                 DT              PRON               DT              this
# most                 RBS             ADV                RBS             most
# common               JJ              ADJ                JJ              common
# mistake              NN              NOUN               NN              mistake
# amateurs             NNS             NOUN               NNS             amateur
# Going                VBG             VERB               VBG             go
# big                  JJ              ADJ                JJ              big
# numbers              NNS             NOUN               NNS             number
# satisfy              VB              VERB               VB              satisfy
# managers             NNS             NOUN               NNS             manager
# Anyway               VBP             INTJ               UH              anyway *
# first                JJ              ADJ                JJ              first
# thing                NN              NOUN               NN              thing
# mean                 VBP             VERB               VBP             mean
# part                 NN              NOUN               NN              part
# very                 RB              ADV                RB              very
# important            JJ              ADJ                JJ              important
# clean                VB              VERB               VB              clean
# residue              NN              NOUN               NN              residue
# old                  JJ              ADJ                JJ              old
# polish               JJ              NOUN               NN              polish *
# To                   TO              PART               TO              to
# keep                 VB              VERB               VB              keep
# from                 IN              ADP                IN              from
# being                VBG             AUX                VBG             be
# ruined               VBN             VERB               VBN             ruin
# all                  DT              PRON               DT              all
# you                  PRP             PRON               PRP             you
# need                 VBP             VERB               VBP             need
# rag                  VBP             VERB               VBP             rag
# with                 IN              ADP                IN              with
# some                 DT              DET                DT              some
# cleaning             NN              NOUN               NN              cleaning
# fluid                NN              NOUN               NN              fluid
# If                   IN              SCONJ              IN              if
# caked                VBD             VERB               VBD             cake
# up                   RP              ADP                RP              up
# gunk                 NN              NOUN               NN              gunk
# think                VB              VERB               VB              think
# breathe              NN              VERB               VB              breathe *
# what                 WP              PRON               WP              what
# causes               VBZ             VERB               VBZ             cause
# feet                 NNS             NOUN               NNS             foot
# stink                VB              VERB               VB              stink
# They                 PRP             PRON               PRP             they
# took                 VBD             VERB               VBD             take
# Carfoine             NNP             PROPN              NNP             Carfoine
# off                  IN              ADP                IN              off
# market               NN              NOUN               NN              market
# believe              VBP             VERB               VBP             believe
# It                   PRP             PRON               PRP             it
# few                  JJ              ADJ                JJ              few
# years                NNS             NOUN               NNS             year
# ago                  RB              ADV                RB              ago
# cause                VB              VERB               VB              cause
# leather              JJR             NOUN               NN              leather *
# Now                  RB              ADV                RB              now
# once                 RB              SCONJ              IN              once *
# cleaned              VBD             VERB               VBN             clean *
# dried                VBN             ADJ                JJ              dried *
# Your                 PRP$            PRON               PRP$            your
# base                 NN              NOUN               NN              base
# coat                 NN              NOUN               NN              coat
# can                  MD              AUX                MD              can
# now                  RB              ADV                RB              now
# applied              VBN             VERB               VBN             apply
# Then                 RB              ADV                RB              then
# brush                VBP             VERB               VBP             brush
# tends                VBZ             VERB               VBZ             tend
# Is                   NNP             AUX                VBZ             be *
# more                 RBR             ADV                RBR             more
# gets                 VBZ             VERB               VBZ             get
# rid                  JJ              VERB               VBN             rid *
# second               JJ              ADJ                JJ              second
# just                 RB              ADV                RB              just
# like                 IN              SCONJ              IN              like
# one                  CD              NOUN               NN              one *
# You                  PRP             PRON               PRP             you
# it                   PRP             PRON               PRP             it
# voila                VB              VERB               VB              voila
# your                 PRP$            PRON               PRP$            your
# work                 NN              NOUN               NN              work
# done                 VBN             VERB               VBN             do
# treat                VBP             VERB               VBP             treat
# each                 DT              DET                DT              each
# special              JJ              ADJ                JJ              special
# Care                 NNP             PROPN              NNP             Care
# about                IN              ADP                IN              about
# professional         JJ              ADJ                JJ              professional
# right                JJ              ADJ                JJ              right
# way                  NN              NOUN               NN              way
# wrong                JJ              ADJ                JJ              wrong
# find                 VBP             VERB               VBP             find
# much                 RB              ADV                RB              much
# better               RBR             ADJ                JJR             well *
# long                 JJ              ADJ                JJ              long
# run                  NN              NOUN               NN              run
# dollar               NN              NOUN               NN              dollar
# or                   CC              CCONJ              CC              or
# trying               VBG             VERB               VBG             try
# fast                 RB              ADV                RB              fast
# Unless               IN              SCONJ              IN              unless
# take                 VBP             VERB               VBP             take
# pride                VB              NOUN               NN              pride *
# last                 JJ              VERB               VB              last *
# Craftsmanship        NNP             PROPN              NNP             Craftsmanship
# quality              NN              NOUN               NN              quality
# lack                 NN              NOUN               NN              lack
# give                 VB              VERB               VB              give
# people               NNS             NOUN               NNS             people
# reason               NN              NOUN               NN              reason
# them                 PRP             PRON               PRP             they
# come                 VB              VERB               VB              come
# worlds               NNS             NOUN               NNS             world
# different            JJ              ADJ                JJ              different
# place                NN              NOUN               NN              place
# than                 IN              SCONJ              IN              than
# introduced           VBN             VERB               VBN             introduce
# wear                 JJ              VERB               VB              wear *
# shineable            JJ              ADJ                JJ              shineable
# they                 PRP             PRON               PRP             they
# used                 VBD             VERB               VBD             use
# Casual               NNP             ADJ                JJ              casual *
# clothes              NNS             NOUN               NNS             clothe
# office               NN              NOUN               NN              office
# villain              NN              NOUN               NN              villain
# sneakers             NNS             NOUN               NNS             sneaker
# killing              VBG             VERB               VBG             kill
# business             NN              NOUN               NN              business
#
# Tokens comparados : 222
# Acuerdo           : 191/222 (86.0%)
# Tokens solo NLTK  : 11 (contracciones no divididas)
# Tokens solo spaCy : 10 (subtokenizaciones)

# %% [markdown]
# Para este caso se le va hacer un ajuste temporal ya que Spacy divide contracciones en 2 tokens, lo cual se desalinean los datos

# %% [markdown]
# ### Extraccion de tags

# %%
# NLTK → tuplas (token, tag)
nltk_tags  = [tag for row in df_nltk['pos_tags']
                   for _, tag in row]

# spaCy → tuplas (token, universal_pos, fine_tag, lemma)
spacy_upos = [upos for row in df_spacy['pos_tags_spacy']
                    for _, upos, _, _ in row]
spacy_fine = [fine for row in df_spacy['pos_tags_spacy']
                    for _, _, fine, _ in row]

# %% [markdown]
# ### Metricas comparativas

# %%
print("\n=== MÉTRICAS COMPARATIVAS ===")
print(f"Tags únicos NLTK  (Penn Treebank): {len(set(nltk_tags))}") #Identificadores
print(f"Tags únicos spaCy (Universal POS): {len(set(spacy_upos))}")
print(f"Total tokens NLTK : {len(nltk_tags):,}")
print(f"Total tokens spaCy: {len(spacy_upos):,}")
# Out:
# === MÉTRICAS COMPARATIVAS ===
# Tags únicos NLTK  (Penn Treebank): 35
# Tags únicos spaCy (Universal POS): 17
# Total tokens NLTK : 1,939,001
# Total tokens spaCy: 2,006,990

# %% [markdown]
# #### ── Comparaciones de uso segun la IA ──────────────────────────────
#
# *Para análisis de letras musicales se recomienda spaCy (Universal POS) porque:*
#
# ✓ Sus 17 categorías son más interpretables para comparar géneros
#
# ✓ Separa VERB de AUX, útil para medir densidad verbal real
#
# ✓ Identifica PROPN (nombres propios), relevante en rap/hip-hop
#
# ✓ Incluye lemmatización, útil para calcular vocabulario único
#
# ✓ INTJ captura exclamaciones típicas de letras (oh, yeah, whoa)
#
# *NLTK (Penn Treebank) es útil cuando se necesita:*
#
# ✗ Distinguir VBD vs VBZ vs VBG (tiempos verbales específicos)
#
# ✗ Análisis sintáctico muy fino
#
# ✗ Compatibilidad con recursos lingüísticos académicos

# %% [markdown]
# ### Rendimiento y Velocidad

# %% [markdown]
#  NLTK con su tagger por defecto  procesó el corpus completo en aproximadamente 1 minuto. spaCy, corriendo el pipeline completo, tardó aproximadamente 5 minutos, es decir, 5 veces más.
#
# Ese tiempo extra no es gratuito pero tampoco es en vano. spaCy en un solo pipeline está haciendo tokenización, POS tagging, dependency parsing, lematización y reconocimiento de entidades nombradas (NER). NLTK en el mismo tiempo solo hace tokenización y POS tagging, nada más. Si quisiéramos obtener lo mismo que spaCy con NLTK, tendríamos que encadenar varios módulos por separado, y el tiempo total probablemente superaría al de spaCy.

# %% [markdown]
# ## Justificacion Final

# %% [markdown]
# ##### Las letras musicales no son texto formal. Son textos con estructuras no convencionales, mucho vocabulario coloquial, repeticiones, onomatopeyas y
# ##### expresiones propias de cada género. Con regularidad las canciones utilizan exclamaciones o dichos populares, que no sea se pueda capturar esto podría
# ##### generar un efecto negativo y una mál análisis de palabras. Dado el análisis previo y a la información otórgado por la IA, se puede aprobar el uso de Spacy
# ##### antes que NLTK, ya que a pesar de sus tiempos de ejecución y velocidad. Se obtienen mejores resultados para el caso de extracción de información en
# ##### música, ádemas otorga más información en pasos más simples
